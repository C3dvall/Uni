# %%
import random as rand
class cards():
  cards = []

  def create(self):
    values = ['2', '3', '4', '5', '6', '7', '8', '9', 'T', 'J', 'Q', 'K', 'A']
    suits = ['s', 'h', 'd', 'c']
    self.cards = []
    for suit in suits:
        for value in values:
            card = value + suit
            self.cards.append(card)

    print("Created deck:\n", self.cards)

  def shuffle(self):
    length = len(self.cards)
    for i in range(0, length):
      r = rand.randint(0, length - 1)
      temp = self.cards[i]
      self.cards[i] = self.cards[r]
      self.cards[r] = temp
    print("Shuffled deck:\n", self.cards)
    return cards

  def deal(self, hands, card_num):
    playerHands = {f"Player {i+1}": [] for i in range(hands)}

    for i in range(0, card_num):
      for hand in playerHands:
        if self.cards:
          playerHands[hand].append(self.cards.pop())
    return playerHands


card_01 = cards()
card_01.create()
card_01.shuffle()
hands = newDeck.deal(2, 5)
print("Dealt hands:\n", hands)
# Out:
# Created deck:
#  ['2s', '3s', '4s', '5s', '6s', '7s', '8s', '9s', 'Ts', 'Js', 'Qs', 'Ks', 'As', '2h', '3h', '4h', '5h', '6h', '7h', '8h', '9h', 'Th', 'Jh', 'Qh', 'Kh', 'Ah', '2d', '3d', '4d', '5d', '6d', '7d', '8d', '9d', 'Td', 'Jd', 'Qd', 'Kd', 'Ad', '2c', '3c', '4c', '5c', '6c', '7c', '8c', '9c', 'Tc', 'Jc', 'Qc', 'Kc', 'Ac']
# Shuffled deck:
#  ['9h', '4s', '5c', '9d', 'Qd', '2h', '7s', 'Qs', 'Kh', '2c', 'Th', 'As', '5h', '8s', '8d', 'Ac', '6d', 'Ah', '4c', '9s', 'Ad', 'Jh', 'Ks', '9c', '7d', '5s', 'Qc', '3c', 'Tc', '3s', 'Ts', '2s', '6c', 'Qh', '6h', '2d', 'Td', 'Jc', '7h', '6s', '3d', '4h', '3h', 'Kd', '7c', '8h', 'Js', '5d', 'Kc', '8c', '4d', 'Jd']
# ['9h', 'Jh', '5c', '2c', '9s', 'Th', '6c', '3d', '4c', 'Kh', '5d', '3h', '3s', '7c', '8c', '5h', 'Jd', '4d', '8h', '7s', 'Qd', '8d']
# Dealt hands:
#  {'Player 1': ['9d', '6s', '2d', 'Ks', '3c'], 'Player 2': ['Ad', 'Js', 'Qc', 'Qs', '4h']}
